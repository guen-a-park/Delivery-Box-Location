# %% [markdown]
# # **Folium 설치 및 실행환경구축**

# %%
pip install folium

# %%
import folium
folium.__version__
# Out:
# '0.8.3'

# %%
import os.path
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina'
 
#한글 출력
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

import matplotlib.font_manager as fm

path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf'
font_name = fm.FontProperties(fname=path, size=10).get_name()
plt.rc('font', family=font_name)
fm._rebuild()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#각자 데이터 있는 경로 지정하기
# %cd /content/drive/MyDrive/공공 빅데이터 분석 공모전/공모전-Folium
# Out:
# /content/drive/MyDrive/공모전 정리 파일

# %% [markdown]
# #**Folium으로 지도위에 숫자데이터 시각화**

# %%
#folium 실행확인
m = folium.Map(location=[45.5236, -122.6750],zoom_start=13)
m
#html로 저장하기
#m.save("example.html")

# %%
#geojson 실행되는지 확인
geo_data = 'jongno_dong.geojson'

m = folium.Map(
    location=[37.541, 126.986],
    tiles="cartodbpositron",
    zoom_start=12,
)

folium.GeoJson(geo_data).add_to(m)
m
#실행안되면 저장해보기
#m.save("example2.html")

# %%
#csv 읽어오기
data = pd.read_csv('folium-example4.csv',engine='python',encoding='CP949')
data.head(5)
# Out:
#      동  1인가구수
# 0  사직동   1487
# 1  삼청동    380
# 2  부암동   1129
# 3  평창동   1302
# 4  무악동    494

# %%
#숫자 데이터 지도위에 시각화하기

# 서울시 중심부의 위도, 경도
center = [37.541, 126.986]

# zoom 레벨은 조정해 맵 만들기,tile 바꾸면 스타일 바뀜
#https://deparkes.co.uk/2016/06/10/folium-map-tiles/
population_map = folium.Map(location=center,tiles='Open street map', zoom_start=12)

# Choropleth 레이어를 만들기
population_map.choropleth(
    geo_data=geo_data,
    data=data,
    columns=['동', '1인가구수'],
    key_on='feature.properties.name',
    fill_color='BuPu',
    legend_name='number',
    smooth_factor=0)

# add tile layers to the map
tiles = ['stamenwatercolor', 'cartodbpositron', 'openstreetmap', 'stamenterrain']
for tile in tiles:
    folium.TileLayer(tile).add_to(population_map)

#tile 바꾸기 상자
folium.LayerControl().add_to(population_map)

# 맵을 출력
population_map

# %% [markdown]
# # **Google Map Api**
# 무인택배함 위,경도 출력. 재실행 필요는 없음

# %%
pip install -U googlemaps

# %%
import csv
import googlemaps

# 위치를 찾을 장소나 주소 지정 
# hwp 파일 참고해서 2021 기준 사용가능한곳 csv 만듦-> 데이터 정제과정 ppt 간략하게 설명하기

#csv 파일 list로 convert
f = open("location2.csv","rt")
csvfile = csv.reader(f)
places = []

for item in csvfile:
  places.append(item)

#2차원으로 저장돼서 1차원으로 차원축소
places = sum(places, [])
print(places)

#데이터 찾기에 실패한 주소 정제
# Out:
# ['\ufeff청운효자동 자치회관', '종로육아종합지원센터', '숭인1동 주민센터', '숭인제2동주민센터', '종로구민회관(문화센터)', '약수동 공영주차장', '버티 공영주차장', '명동주민센터', '장충체육관 후문', '약수교회 식당입구', '장충공영주차장', '충현 공영주차장', '다산동공영주차장', '보광동주민센터', '효창종합사회복지관', '숙대 명재관 인근', '용산치안센터', '효창동주민센터', '한남동공영주차장', '용산구청후문', '갈월종합사회복지관', '용산꿈나무종합타운', '열린금호교육문화관', '성수2가1동공영주차장', '성수2가3동공영주차장', '용답건물', '강변공영주차장', '하왕십리공영주차장', '성동구민종합체육센터', '성동구립도서관', '이든 아이빌', '사근동주민센터', '자양2동주민센터', '구의1동 공영주차장', '중곡감리교회', '구의2동 공동주차장', '자양종합사회복지관', '중곡문화체육센터', '중곡종합건강센터', '화양동주민센터', '자양4동 주민센터', '동부여성발전센터', '중곡1동주민센터', '광진경찰서', '현대오일뱅크 중원점', '휘경마을공영주차장', '진성경로당', '신한은행 외대역 지점', '나사렛 교회', '장안2동 공영주차장', '동대문구청 종합민원실', '동대문종합사회복지관', '회기동공영주차장', '답십리도서관', '정보화도서관', '장안종합사회복지관', '시립동대문청소년센터', '망우3동 공영주차장', '상봉1동주민센터', '면목4동주민센터', '면목5동 주민센터', '면목본동 주민센터', '상봉2동 주민센터', '석관동주민센터', '보문 부모아이지원센터', '제일빌딩(고대인근)', '성북희망나눔봉사센터', '안암교회', '아리랑 시네미디어센터', '장위1동 주민센터', '성북청소년수련관', '강북노인종합복지관', '솔밭근린공원 개방화장실', '강북문화예술회관', '번동북부시장 북부마트', '수유역1번출구', '미아동 복합청사', '강북구청 본관 입구', '수유1동 주민센터', '도봉구민청', '염광교회', '창3동 주민센터', '도봉구민회관', '창1동제1공영주차장', '창동 도봉육아종합지원센터', '도봉서원종합사회복지관', '방아골종합사회복지관', '창동역1번출구', '도봉1동주민센터', '신창교회', '공릉종합사회복지관', '상계문화정보도서관', '상계2동주민센터', '월계문화정보도서관', '상계3,4동 주민센터', '상계역 자전거대여소', '공릉 청소년문화정보센터', '공릉1동 주민센터', '월계치안센터', '역촌동 주민센터', '갈현1동 주민센터', '아인스하임', '갈현청소년센터쉼쉼', '시립은평청소년센터', '연신내 지구대', '불광보건분소', '구산동주민센터', '신사종합사회복지관', '불광1동 치안센터', '녹번 119안전센터', '증산 정보도서관', '청년누리', '남가좌2동제2공영주차장', '남가좌새롬어린이도서관', '신한은행 명지대 지점', '홍제3동 주민센터', '홍은2동 주민센터', '연희동주민센터', '홍은1동주민센터', '홍성교회', '서부제일교회 어린이도서관', '봉원교회', '북아현동 주민센터', '충현동주민센터', '서교동교회', '성산1동주민센터', '서강동주민센터', '상암동주민센터', '신수동주민센터', '성산2동주민센터', '연남동희망원룸주택', '상암동 제1공영주차장', '마포아트센터', '우리마포복지관', '연남동 주민커뮤니티센터', '도화동 주민센터', '신월1동 청소년독서실', '양천나눔누리센터', '목동실버복지문화센터', '신정4동주민센터', '목동문화체육센터', '신월문화체육센터', '신월5동주민센터', '신월4동주민센터', '목3동 주민센터', '목동보건지소', '신월3동주민센터', '길꽃어린이 도서관', '신방화역환승주차장', '화곡8동 주민센터', '가로공원공영주차장1번출구', '화곡 6-1 공영주차장', '화곡 3-1 공영주차장', '화곡 1-1 공영주차장', '내발산동 문화센터', '곰달래복지문화센터', '화곡4동 주민센터', '볏골공원공원주차장', '공항동 주민센터', '발산1동주민센터', '가리봉동주민센터', '동양미래대학교 기숙사', '중앙경로당', '구로구 시설관리공단', '서울메트로대림별관', '온수동 공동이용시설', '궁동종합사회복지관', '구로역1번출구 AK플라자입구', '구로구민회관', '구로구민 체육센터', '구로2동주민센터앞', '오류1동텃골공영주차장', '현대오일뱅크 구로셀프점', '독산2동주민센터', '금하마을주민공동이용시설', '금빛휘트니스센터', '가산동주민센터', '시흥4동 주민센터', '금천호암노인복지관', '시흥3동 주민센터', '독산1동주민센터', '금천구청', '영등포구청소년 상담복지센터', '영등포제1스포츠센터', '신길6동 복지관', '영등포평생학습관', '영등포본동주민센터', '신길4동1동1마을공영주차장', '신길7동 주민센터', '도림동 주민센터', '신길1동 주민센터', '대림정보문화도서관', '그린케어센터', '다울도서관', '신한은행 숭실대역 지점', '순만빌딩', '사당문화회관', '상도1동주민센터', '예그리나주택', '강남교회 교육관', '동작 청소년문화의 집', '우리은행 동작구청지점', '사당노인종합복지관', '상도3동 주민센터', '신대방해피점', '현대오일뱅크 사당셀프점', '미성동자치회관', '행복경로당', '신한은행 (구)봉천서 지점', '신한은행 신림대학동 지점', '서원동 주민센터', '관악청소년회관', '인헌동주민센터', '대학동치안센터', '남현동 주민센터', '청룡동 주민센터', '조원동주민센터', '신사동자치회관', '행운동주민센터', '관악구청', '신림여성회관', '현대오일뱅크 관악셀프점', '방음언덕형공영주차장', '양재1동 민원분소', '양재2동주민센터', '언구비 공영주차장', '방배열린문화센터', '방배2동 주민센터', '서초꿈나무라이온스 보금자리', '역삼청소년수련관', '대치2동 주민센터', '도곡1동 주민센터', '논현1동주민센터', '대치4동 주민센터', '도곡2동주민센터', '일원1동주민센터', '역삼1동 주민센터', '현대오일뱅크 신사현대점', '가락2동치안센터', '장지동 주민센터', '거여2동주민센터', '마천2동주민센터', '석촌동주민센터', '송파노인종합복지관', '여의도 순복음송파교회', '송파여성 문화회관', '거여1동주민센터', '문정1동주민센터', '삼전지구대', '2001아울렛천호점', '성내1동 주민센터', '암사2동 주민센터', '강동구민회관', '강동구 청소년회관', '강동평생학습센터', '강동구립암사도서관', '강동구립해공도서관', '길동주민센터']

# %%
#발급받은 api key 넣기
my_key = "AIzaSyCCKmIspjP6FR9PPFZEP7lkiGMegX-RRdc"
maps = googlemaps.Client(key=my_key)  # my key값 입력
lat = []  #위도
lng = []  #경도

# places = ["청운효자동 자치회관",
# "종로육아종합지원센터",
# "숭인1동 주민센터"]

i=0
for place in places:   
    i = i + 1
    try:
        print("%d번 인덱스에서 %s의 위치를 찾고있습니다"%(i, place))
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df = pd.DataFrame({'lat':lat, 'lng':lng}, index=places)
#df.head(5)
# Out:
# 1번 인덱스에서 ﻿청운효자동 자치회관의 위치를 찾고있습니다
# 2번 인덱스에서 종로육아종합지원센터의 위치를 찾고있습니다
# 3번 인덱스에서 숭인1동 주민센터의 위치를 찾고있습니다
# 4번 인덱스에서 숭인제2동주민센터의 위치를 찾고있습니다
# 5번 인덱스에서 종로구민회관(문화센터)의 위치를 찾고있습니다
# 6번 인덱스에서 약수동 공영주차장의 위치를 찾고있습니다
# 7번 인덱스에서 버티 공영주차장의 위치를 찾고있습니다
# 8번 인덱스에서 명동주민센터의 위치를 찾고있습니다
# 9번 인덱스에서 장충체육관 후문의 위치를 찾고있습니다
# 10번 인덱스에서 약수교회 식당입구의 위치를 찾고있습니다
# 11번 인덱스에서 장충공영주차장의 위치를 찾고있습니다
# 12번 인덱스에서 충현 공영주차장의 위치를 찾고있습니다
# 13번 인덱스에서 다산동공영주차장의 위치를 찾고있습니다
# 14번 인덱스에서 보광동주민센터의 위치를 찾고있습니다
# 15번 인덱스에서 효창종합사회복지관의 위치를 찾고있습니다
# 16번 인덱스에서 숙대 명재관 인근의 위치를 찾고있습니다
# 17번 인덱스에서 용산치안센터의 위치를 찾고있습니다
# 18번 인덱스에서 효창동주민센터의 위치를 찾고있습니다
# 19번 인덱스에서 한남동공영주차장의 위치를 찾고있습니다
# 20번 인덱스에서 용산구청후문의 위치를 찾고있습니다
# 21번 인덱스에서 갈월종합사회복지관의 위치를 찾고있습니다
# 22번 인덱스에서 용산꿈나무종합타운의 위치를 찾고있습니다
# 23번 인덱스에서 열린금호교육문화관의 위치를 찾고있습니다
# 24번 인덱스에서 성수2가1동공영주차장의 위치를 찾고있습니다
# 25번 인덱스에서 성수2가3동공영주차장의 위치를 찾고있습니다
# 26번 인덱스에서 용답건물의 위치를 찾고있습니다
# 27번 인덱스에서 강변공영주차장의 위치를 찾고있습니다
# 28번 인덱스에서 하왕십리공영주차장의 위치를 찾고있습니다
# 29번 인덱스에서 성동구민종합체육센터의 위치를 찾고있습니다
# 30번 인덱스에서 성동구립도서관의 위치를 찾고있습니다
# 31번 인덱스에서 이든 아이빌의 위치를 찾고있습니다
# 32번 인덱스에서 사근동주민센터의 위치를 찾고있습니다
# 33번 인덱스에서 자양2동주민센터의 위치를 찾고있습니다
# 34번 인덱스에서 구의1동 공영주차장의 위치를 찾고있습니다
# 34번 인덱스 위치를 찾는데 실패했습니다.
# 35번 인덱스에서 중곡감리교회의 위치를 찾고있습니다
# 36번 인덱스에서 구의2동 공동주차장의 위치를 찾고있습니다
# 36번 인덱스 위치를 찾는데 실패했습니다.
# 37번 인덱스에서 자양종합사회복지관의 위치를 찾고있습니다
# 38번 인덱스에서 중곡문화체육센터의 위치를 찾고있습니다
# 39번 인덱스에서 중곡종합건강센터의 위치를 찾고있습니다
# 40번 인덱스에서 화양동주민센터의 위치를 찾고있습니다
# 41번 인덱스에서 자양4동 주민센터의 위치를 찾고있습니다
# 42번 인덱스에서 동부여성발전센터의 위치를 찾고있습니다
# 43번 인덱스에서 중곡1동주민센터의 위치를 찾고있습니다
# 44번 인덱스에서 광진경찰서의 위치를 찾고있습니다
# 45번 인덱스에서 현대오일뱅크 중원점의 위치를 찾고있습니다
# 46번 인덱스에서 휘경마을공영주차장의 위치를 찾고있습니다
# 47번 인덱스에서 진성경로당의 위치를 찾고있습니다
# 48번 인덱스에서 신한은행 외대역 지점의 위치를 찾고있습니다
# 49번 인덱스에서 나사렛 교회의 위치를 찾고있습니다
# 50번 인덱스에서 장안2동 공영주차장의 위치를 찾고있습니다
# 51번 인덱스에서 동대문구청 종합민원실의 위치를 찾고있습니다
# 52번 인덱스에서 동대문종합사회복지관의 위치를 찾고있습니다
# 53번 인덱스에서 회기동공영주차장의 위치를 찾고있습니다
# 54번 인덱스에서 답십리도서관의 위치를 찾고있습니다
# 55번 인덱스에서 정보화도서관의 위치를 찾고있습니다
# 56번 인덱스에서 장안종합사회복지관의 위치를 찾고있습니다
# 57번 인덱스에서 시립동대문청소년센터의 위치를 찾고있습니다
# 58번 인덱스에서 망우3동 공영주차장의 위치를 찾고있습니다
# 59번 인덱스에서 상봉1동주민센터의 위치를 찾고있습니다
# 60번 인덱스에서 면목4동주민센터의 위치를 찾고있습니다
# 61번 인덱스에서 면목5동 주민센터의 위치를 찾고있습니다
# 62번 인덱스에서 면목본동 주민센터의 위치를 찾고있습니다
# 63번 인덱스에서 상봉2동 주민센터의 위치를 찾고있습니다
# 64번 인덱스에서 석관동주민센터의 위치를 찾고있습니다
# 65번 인덱스에서 보문 부모아이지원센터의 위치를 찾고있습니다
# 66번 인덱스에서 제일빌딩(고대인근)의 위치를 찾고있습니다
# 67번 인덱스에서 성북희망나눔봉사센터의 위치를 찾고있습니다
# 68번 인덱스에서 안암교회의 위치를 찾고있습니다
# 69번 인덱스에서 아리랑 시네미디어센터의 위치를 찾고있습니다
# 70번 인덱스에서 장위1동 주민센터의 위치를 찾고있습니다
# 71번 인덱스에서 성북청소년수련관의 위치를 찾고있습니다
# 72번 인덱스에서 강북노인종합복지관의 위치를 찾고있습니다
# 73번 인덱스에서 솔밭근린공원 개방화장실의 위치를 찾고있습니다
# 74번 인덱스에서 강북문화예술회관의 위치를 찾고있습니다
# 75번 인덱스에서 번동북부시장 북부마트의 위치를 찾고있습니다
# 76번 인덱스에서 수유역1번출구의 위치를 찾고있습니다
# 77번 인덱스에서 미아동 복합청사의 위치를 찾고있습니다
# 78번 인덱스에서 강북구청 본관 입구의 위치를 찾고있습니다
# 79번 인덱스에서 수유1동 주민센터의 위치를 찾고있습니다
# 80번 인덱스에서 도봉구민청의 위치를 찾고있습니다
# 81번 인덱스에서 염광교회의 위치를 찾고있습니다
# 82번 인덱스에서 창3동 주민센터의 위치를 찾고있습니다
# 83번 인덱스에서 도봉구민회관의 위치를 찾고있습니다
# 84번 인덱스에서 창1동제1공영주차장의 위치를 찾고있습니다
# 85번 인덱스에서 창동 도봉육아종합지원센터의 위치를 찾고있습니다
# 86번 인덱스에서 도봉서원종합사회복지관의 위치를 찾고있습니다
# 87번 인덱스에서 방아골종합사회복지관의 위치를 찾고있습니다
# 88번 인덱스에서 창동역1번출구의 위치를 찾고있습니다
# 89번 인덱스에서 도봉1동주민센터의 위치를 찾고있습니다
# 90번 인덱스에서 신창교회의 위치를 찾고있습니다
# 91번 인덱스에서 공릉종합사회복지관의 위치를 찾고있습니다
# 92번 인덱스에서 상계문화정보도서관의 위치를 찾고있습니다
# 93번 인덱스에서 상계2동주민센터의 위치를 찾고있습니다
# 94번 인덱스에서 월계문화정보도서관의 위치를 찾고있습니다
# 95번 인덱스에서 상계3,4동 주민센터의 위치를 찾고있습니다
# 96번 인덱스에서 상계역 자전거대여소의 위치를 찾고있습니다
# 97번 인덱스에서 공릉 청소년문화정보센터의 위치를 찾고있습니다
# 98번 인덱스에서 공릉1동 주민센터의 위치를 찾고있습니다
# 99번 인덱스에서 월계치안센터의 위치를 찾고있습니다
# 100번 인덱스에서 역촌동 주민센터의 위치를 찾고있습니다
# 101번 인덱스에서 갈현1동 주민센터의 위치를 찾고있습니다
# 102번 인덱스에서 아인스하임의 위치를 찾고있습니다
# 103번 인덱스에서 갈현청소년센터쉼쉼의 위치를 찾고있습니다
# 104번 인덱스에서 시립은평청소년센터의 위치를 찾고있습니다
# 105번 인덱스에서 연신내 지구대의 위치를 찾고있습니다
# 106번 인덱스에서 불광보건분소의 위치를 찾고있습니다
# 107번 인덱스에서 구산동주민센터의 위치를 찾고있습니다
# 108번 인덱스에서 신사종합사회복지관의 위치를 찾고있습니다
# 109번 인덱스에서 불광1동 치안센터의 위치를 찾고있습니다
# 109번 인덱스 위치를 찾는데 실패했습니다.
# 110번 인덱스에서 녹번 119안전센터의 위치를 찾고있습니다
# 111번 인덱스에서 증산 정보도서관의 위치를 찾고있습니다
# 112번 인덱스에서 청년누리의 위치를 찾고있습니다
# 113번 인덱스에서 남가좌2동제2공영주차장의 위치를 찾고있습니다
# 114번 인덱스에서 남가좌새롬어린이도서관의 위치를 찾고있습니다
# 115번 인덱스에서 신한은행 명지대 지점의 위치를 찾고있습니다
# 116번 인덱스에서 홍제3동 주민센터의 위치를 찾고있습니다
# 117번 인덱스에서 홍은2동 주민센터의 위치를 찾고있습니다
# 118번 인덱스에서 연희동주민센터의 위치를 찾고있습니다
# 119번 인덱스에서 홍은1동주민센터의 위치를 찾고있습니다
# 120번 인덱스에서 홍성교회의 위치를 찾고있습니다
# 121번 인덱스에서 서부제일교회 어린이도서관의 위치를 찾고있습니다
# 122번 인덱스에서 봉원교회의 위치를 찾고있습니다
# 123번 인덱스에서 북아현동 주민센터의 위치를 찾고있습니다
# 124번 인덱스에서 충현동주민센터의 위치를 찾고있습니다
# 125번 인덱스에서 서교동교회의 위치를 찾고있습니다
# 126번 인덱스에서 성산1동주민센터의 위치를 찾고있습니다
# 127번 인덱스에서 서강동주민센터의 위치를 찾고있습니다
# 128번 인덱스에서 상암동주민센터의 위치를 찾고있습니다
# 129번 인덱스에서 신수동주민센터의 위치를 찾고있습니다
# 130번 인덱스에서 성산2동주민센터의 위치를 찾고있습니다
# 131번 인덱스에서 연남동희망원룸주택의 위치를 찾고있습니다
# 132번 인덱스에서 상암동 제1공영주차장의 위치를 찾고있습니다
# 133번 인덱스에서 마포아트센터의 위치를 찾고있습니다
# 134번 인덱스에서 우리마포복지관의 위치를 찾고있습니다
# 135번 인덱스에서 연남동 주민커뮤니티센터의 위치를 찾고있습니다
# 136번 인덱스에서 도화동 주민센터의 위치를 찾고있습니다
# 137번 인덱스에서 신월1동 청소년독서실의 위치를 찾고있습니다
# 138번 인덱스에서 양천나눔누리센터의 위치를 찾고있습니다
# 138번 인덱스 위치를 찾는데 실패했습니다.
# 139번 인덱스에서 목동실버복지문화센터의 위치를 찾고있습니다
# 140번 인덱스에서 신정4동주민센터의 위치를 찾고있습니다
# 141번 인덱스에서 목동문화체육센터의 위치를 찾고있습니다
# 142번 인덱스에서 신월문화체육센터의 위치를 찾고있습니다
# 143번 인덱스에서 신월5동주민센터의 위치를 찾고있습니다
# 144번 인덱스에서 신월4동주민센터의 위치를 찾고있습니다
# 145번 인덱스에서 목3동 주민센터의 위치를 찾고있습니다
# 146번 인덱스에서 목동보건지소의 위치를 찾고있습니다
# 147번 인덱스에서 신월3동주민센터의 위치를 찾고있습니다
# 148번 인덱스에서 길꽃어린이 도서관의 위치를 찾고있습니다
# 149번 인덱스에서 신방화역환승주차장의 위치를 찾고있습니다
# 150번 인덱스에서 화곡8동 주민센터의 위치를 찾고있습니다
# 151번 인덱스에서 가로공원공영주차장1번출구의 위치를 찾고있습니다
# 152번 인덱스에서 화곡 6-1 공영주차장의 위치를 찾고있습니다
# 153번 인덱스에서 화곡 3-1 공영주차장의 위치를 찾고있습니다
# 154번 인덱스에서 화곡 1-1 공영주차장의 위치를 찾고있습니다
# 155번 인덱스에서 내발산동 문화센터의 위치를 찾고있습니다
# 156번 인덱스에서 곰달래복지문화센터의 위치를 찾고있습니다
# 157번 인덱스에서 화곡4동 주민센터의 위치를 찾고있습니다
# 158번 인덱스에서 볏골공원공원주차장의 위치를 찾고있습니다
# 159번 인덱스에서 공항동 주민센터의 위치를 찾고있습니다
# 160번 인덱스에서 발산1동주민센터의 위치를 찾고있습니다
# 161번 인덱스에서 가리봉동주민센터의 위치를 찾고있습니다
# 162번 인덱스에서 동양미래대학교 기숙사의 위치를 찾고있습니다
# 163번 인덱스에서 중앙경로당의 위치를 찾고있습니다
# 164번 인덱스에서 구로구 시설관리공단의 위치를 찾고있습니다
# 165번 인덱스에서 서울메트로대림별관의 위치를 찾고있습니다
# 166번 인덱스에서 온수동 공동이용시설의 위치를 찾고있습니다
# 167번 인덱스에서 궁동종합사회복지관의 위치를 찾고있습니다
# 168번 인덱스에서 구로역1번출구 AK플라자입구의 위치를 찾고있습니다
# 169번 인덱스에서 구로구민회관의 위치를 찾고있습니다
# 170번 인덱스에서 구로구민 체육센터의 위치를 찾고있습니다
# 171번 인덱스에서 구로2동주민센터앞의 위치를 찾고있습니다
# 172번 인덱스에서 오류1동텃골공영주차장의 위치를 찾고있습니다
# 173번 인덱스에서 현대오일뱅크 구로셀프점의 위치를 찾고있습니다
# 174번 인덱스에서 독산2동주민센터의 위치를 찾고있습니다
# 175번 인덱스에서 금하마을주민공동이용시설의 위치를 찾고있습니다
# 176번 인덱스에서 금빛휘트니스센터의 위치를 찾고있습니다
# 177번 인덱스에서 가산동주민센터의 위치를 찾고있습니다
# 178번 인덱스에서 시흥4동 주민센터의 위치를 찾고있습니다
# 179번 인덱스에서 금천호암노인복지관의 위치를 찾고있습니다
# 180번 인덱스에서 시흥3동 주민센터의 위치를 찾고있습니다
# 181번 인덱스에서 독산1동주민센터의 위치를 찾고있습니다
# 182번 인덱스에서 금천구청의 위치를 찾고있습니다
# 183번 인덱스에서 영등포구청소년 상담복지센터의 위치를 찾고있습니다
# 184번 인덱스에서 영등포제1스포츠센터의 위치를 찾고있습니다
# 185번 인덱스에서 신길6동 복지관의 위치를 찾고있습니다
# 186번 인덱스에서 영등포평생학습관의 위치를 찾고있습니다
# 187번 인덱스에서 영등포본동주민센터의 위치를 찾고있습니다
# 188번 인덱스에서 신길4동1동1마을공영주차장의 위치를 찾고있습니다
# 189번 인덱스에서 신길7동 주민센터의 위치를 찾고있습니다
# 190번 인덱스에서 도림동 주민센터의 위치를 찾고있습니다
# 191번 인덱스에서 신길1동 주민센터의 위치를 찾고있습니다
# 192번 인덱스에서 대림정보문화도서관의 위치를 찾고있습니다
# 193번 인덱스에서 그린케어센터의 위치를 찾고있습니다
# 194번 인덱스에서 다울도서관의 위치를 찾고있습니다
# 195번 인덱스에서 신한은행 숭실대역 지점의 위치를 찾고있습니다
# 196번 인덱스에서 순만빌딩의 위치를 찾고있습니다
# 197번 인덱스에서 사당문화회관의 위치를 찾고있습니다
# 198번 인덱스에서 상도1동주민센터의 위치를 찾고있습니다
# 199번 인덱스에서 예그리나주택의 위치를 찾고있습니다
# 200번 인덱스에서 강남교회 교육관의 위치를 찾고있습니다
# 201번 인덱스에서 동작 청소년문화의 집의 위치를 찾고있습니다
# 202번 인덱스에서 우리은행 동작구청지점의 위치를 찾고있습니다
# 203번 인덱스에서 사당노인종합복지관의 위치를 찾고있습니다
# 204번 인덱스에서 상도3동 주민센터의 위치를 찾고있습니다
# 205번 인덱스에서 신대방해피점의 위치를 찾고있습니다
# 206번 인덱스에서 현대오일뱅크 사당셀프점의 위치를 찾고있습니다
# 207번 인덱스에서 미성동자치회관의 위치를 찾고있습니다
# 208번 인덱스에서 행복경로당의 위치를 찾고있습니다
# 209번 인덱스에서 신한은행 (구)봉천서 지점의 위치를 찾고있습니다
# 210번 인덱스에서 신한은행 신림대학동 지점의 위치를 찾고있습니다
# 211번 인덱스에서 서원동 주민센터의 위치를 찾고있습니다
# 212번 인덱스에서 관악청소년회관의 위치를 찾고있습니다
# 213번 인덱스에서 인헌동주민센터의 위치를 찾고있습니다
# 214번 인덱스에서 대학동치안센터의 위치를 찾고있습니다
# 215번 인덱스에서 남현동 주민센터의 위치를 찾고있습니다
# 216번 인덱스에서 청룡동 주민센터의 위치를 찾고있습니다
# 217번 인덱스에서 조원동주민센터의 위치를 찾고있습니다
# 218번 인덱스에서 신사동자치회관의 위치를 찾고있습니다
# 219번 인덱스에서 행운동주민센터의 위치를 찾고있습니다
# 220번 인덱스에서 관악구청의 위치를 찾고있습니다
# 221번 인덱스에서 신림여성회관의 위치를 찾고있습니다
# 222번 인덱스에서 현대오일뱅크 관악셀프점의 위치를 찾고있습니다
# 223번 인덱스에서 방음언덕형공영주차장의 위치를 찾고있습니다
# 224번 인덱스에서 양재1동 민원분소의 위치를 찾고있습니다
# 225번 인덱스에서 양재2동주민센터의 위치를 찾고있습니다
# 226번 인덱스에서 언구비 공영주차장의 위치를 찾고있습니다
# 227번 인덱스에서 방배열린문화센터의 위치를 찾고있습니다
# 228번 인덱스에서 방배2동 주민센터의 위치를 찾고있습니다
# 229번 인덱스에서 서초꿈나무라이온스 보금자리의 위치를 찾고있습니다
# 230번 인덱스에서 역삼청소년수련관의 위치를 찾고있습니다
# 231번 인덱스에서 대치2동 주민센터의 위치를 찾고있습니다
# 232번 인덱스에서 도곡1동 주민센터의 위치를 찾고있습니다
# 233번 인덱스에서 논현1동주민센터의 위치를 찾고있습니다
# 234번 인덱스에서 대치4동 주민센터의 위치를 찾고있습니다
# 235번 인덱스에서 도곡2동주민센터의 위치를 찾고있습니다
# 236번 인덱스에서 일원1동주민센터의 위치를 찾고있습니다
# 237번 인덱스에서 역삼1동 주민센터의 위치를 찾고있습니다
# 238번 인덱스에서 현대오일뱅크 신사현대점의 위치를 찾고있습니다
# 239번 인덱스에서 가락2동치안센터의 위치를 찾고있습니다
# 240번 인덱스에서 장지동 주민센터의 위치를 찾고있습니다
# 241번 인덱스에서 거여2동주민센터의 위치를 찾고있습니다
# 242번 인덱스에서 마천2동주민센터의 위치를 찾고있습니다
# 243번 인덱스에서 석촌동주민센터의 위치를 찾고있습니다
# 244번 인덱스에서 송파노인종합복지관의 위치를 찾고있습니다
# 245번 인덱스에서 여의도 순복음송파교회의 위치를 찾고있습니다
# 246번 인덱스에서 송파여성 문화회관의 위치를 찾고있습니다
# 247번 인덱스에서 거여1동주민센터의 위치를 찾고있습니다
# 248번 인덱스에서 문정1동주민센터의 위치를 찾고있습니다
# 249번 인덱스에서 삼전지구대의 위치를 찾고있습니다
# 250번 인덱스에서 2001아울렛천호점의 위치를 찾고있습니다
# 251번 인덱스에서 성내1동 주민센터의 위치를 찾고있습니다
# 252번 인덱스에서 암사2동 주민센터의 위치를 찾고있습니다
# 253번 인덱스에서 강동구민회관의 위치를 찾고있습니다
# 254번 인덱스에서 강동구 청소년회관의 위치를 찾고있습니다
# 255번 인덱스에서 강동평생학습센터의 위치를 찾고있습니다
# 256번 인덱스에서 강동구립암사도서관의 위치를 찾고있습니다
# 257번 인덱스에서 강동구립해공도서관의 위치를 찾고있습니다
# 258번 인덱스에서 길동주민센터의 위치를 찾고있습니다

# %%
#시각화시 결측치 더 찾음
#위도 37.413294 보다 작은 행, 경도 최소값인 행찾기

error1 = df['lat'] < 37.413294 #162,207,215
subset_df = df[error2]

error1 = df['lng'].min() #207
# Out:
# 126.7530028               lat      lng
# 중앙경로당      35.543  128.488
# 행복경로당     36.1205  126.753
# 청룡동 주민센터   36.786  127.157

# %%
#결측치 google map 검색 후 직접수정. 대부분 지명이 조금 변경거나 다른 동일지명 때문에 오류

#33,35,46,48,74,80,108,111,137,192,193,204 인덱스 잘못됨

df.iloc[[33,35]] = [(37.53830896854011, 127.0878270398395),(37.547209307462786, 127.09005508216892)]
df.iloc[[33,35,46,48,74,80,108,111,137,192,193,204]] = [(37.53830896854011, 127.0878270398395),(37.547209307462786, 127.09005508216892),(37.59438189471257, 127.05968719751229),
(37.580618074547445, 127.05303742883679),(37.636195779723074, 127.02993871665113),(37.651912363204005, 127.03729445522251),(37.61832452069178, 126.93300424567866),
(37.57623598949008, 126.92638632143401),(37.51900504299165, 126.85378777052264),(37.525962769539674, 126.89396033828044),(37.478865490490385, 126.97323508213337),(37.4864472440814, 126.90767106411226)]

df.iloc[[162,207,215]] = [(),()]

print(df.iloc[204])
# Out:
# lat    37.4864
# lng    126.908
# Name: 신대방해피점, dtype: object

# %%
#csv로 저장해서 내보내기
df.to_csv("lat-lng.csv", mode='w')

# %% [markdown]
# # **서울시 여성안심택배함 위치 시각화**

# %%
pip install pyproj==3.0.0.post1

# %%
from pyproj import Transformer
import pyproj
from shapely.geometry import Point as point
#import geopandas as gpd

# %%
# csv 불러오기
parcel = pd.read_csv('lat-lng.csv',engine='python') 
parcel_x = parcel['lat']
parcel_y = parcel['lng']

# %%
#지도의 중심을 지정하기 위해 위도와 경도의 평균 구하기
lati = parcel['lat'].mean()
long = parcel['lng'].mean()

print(lati)
print(long)
# #지도 띄우기
# m = folium.Map(location = [lati, long],tiles="cartodbpositron",zoom_start = 12)

# m
# Out:
# 37.5322347087034
# 126.98750050093945

# %%
m = folium.Map(location = [lati, long],tiles="cartodbpositron",zoom_start = 11)
coords = []
for i in range(len(parcel)-1):
    x = parcel_x[i]
    y = parcel_y[i]
    coords.append([x, y])

#시각화 설정바꾸기, 마크 바꾸기?
for i in range(len(coords)):
    folium.Circle(
        location = coords[i],
        radius = 50,
        color = '#000000',
        fill = 'crimson',
    ).add_to(m)

#시각화
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_1d86d4e221d448ed8e61866265a05a8d%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1d86d4e221d448ed8e61866265a05a8d%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_1d86d4e221d448ed8e61866265a05a8d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_1d86d4e221d448ed8e61866265a05a8d%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.5322347087034%2C%20126.98750050093945%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_4acb287edd8c43749b53da86c1bf900c%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//cartodb-basemaps-%7Bs%7D.global.ssl.fastly.net/light_all/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attr ...
